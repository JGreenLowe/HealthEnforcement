# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import spacy
nlp = spacy.load('en_core_web_md')

working = pd.read_csv("../data/interim/working.csv")
working = working.drop(['Unnamed: 0'], axis=1)
working.head()

## Note: this notebook takes 30 minutes to run, primarily because of cell 5. Please feel free to skip it if you
## have downloaded the repository, as all of the work done by this notebook has been saved in the export file.
# Out:
#         NUM                                           FACILITY        DATE  \
# 0  20008964                          FREMONT HEALTHCARE CENTER  2012-02-01
# 1  20009068                         WILLOW TREE NURSING CENTER  2012-03-02
# 2  20009069  KINDRED NURSING AND REHABILITATION - YGNACIO V...  2012-03-02
# 3  20009078              BAY VIEW REHABILITATION HOSPITAL, LLC  2012-03-05
# 4  20009082                    LONE TREE CONVALESCENT HOSPITAL  2012-03-06
#
#       FINE                                          NARRATIVE
# 0    750.0  F323 483.25(h) FREE OF ACCIDENT HAZARDS/SUPERV...
# 1    750.0  Title 22 72520 (a) If a patient of a skilled n...
# 2    750.0  483.12(b) (3) Permitting Resident to Return to...
# 3  37500.0  483.25 PROVIDE CARE/SERVICES FOR HIGHEST WELL ...
# 4    600.0  T22 DIV5 CH3 ART3-72311(a)(1)(A) Nursing Servi...

# %%
from gensim.models import Phrases

# %%
# Generate a list of strings from the database

corpus = working['NARRATIVE'].tolist()
(corpus[0][0:100], corpus[1][0:100], corpus[2][300:400],), 
(type(corpus), type(corpus[0]))
# Out:
# (list, str)

# %%
# This function will convert a string into a list of unigrams and remove whitespace, punctuation, and stopwords.

def unigrammize(input_text):
    for word in nlp.Defaults.stop_words:
        for w in (word, word[0].upper() + word[1:], word.upper()):
            lex = nlp.vocab[w]
            lex.is_stop = True
        
    lower = nlp(input_text.lower())
    unigrams = [token.lemma_ for token in lower 
                   if (not token.is_stop) and (not token.is_punct) and (not token.is_space)]
    return unigrams

# %%
# %%time

# Convert the corpus into a list of lists of unigrams
unigrams = [unigrammize(document) for document in corpus]
# Out:
# Wall time: 26min 36s

# %%
# View a portion of the unigrams
[unigrams[0][0:10], unigrams[1][0:10], unigrams[2][0:10]]
# Out:
# [['f323',
#   '483.25(h',
#   'free',
#   'accident',
#   'hazard',
#   'supervision',
#   'device',
#   'facility',
#   'ensure',
#   'resident'],
#  ['title',
#   '22',
#   '72520',
#   'patient',
#   'skilled',
#   'nursing',
#   'facility',
#   'transfer',
#   'general',
#   'acute'],
#  ['483.12(b',
#   '3',
#   'permit',
#   'resident',
#   'return',
#   'facility',
#   'nursing',
#   'facility',
#   'establish',
#   'follow']]

# %%
# This function adds bigrams and trigrams to a list of list of unigrams without deleting the original unigrams.

def add_trigrams(unigrams):
    result = []
    bigram_model = Phrases(unigrams, min_count=1, delimiter=b'_')
    trigram_model = Phrases(bigram_model[unigrams], min_count=1, delimiter=b'_')
    
    for document in unigrams:
        bigrams_ = [b for b in bigram_model[document] if b.count('_') == 1]
        trigrams_ = [t for t in trigram_model[bigram_model[document]] if t.count('_') == 2]
        merged_ = trigrams_ + bigrams_ + document
        result.append(merged_)

    return result

# %%
# View a sample of the list of lists that includes trigrams

trigrams = add_trigrams(unigrams)
[trigrams[0][0:30], trigrams[1][0:30], trigrams[2][0:30], trigrams[3][0:30]]
# Out:
# [['hazard_supervision_device',
#   'device_prevent_accident',
#   'facility_violate_regulation',
#   'receive_adequate_supervision',
#   'burn_left_thigh',
#   'area_1.5_x',
#   'accord_recent_minimum',
#   'datum_set_md',
#   'need_extensive_assistance',
#   'use_wheel_walker',
#   'range_motion_joint',
#   'write_6:30_p.m.',
#   'hot_tea_spill',
#   'order_silvadene_cream',
#   'study_thermal_injury',
#   'thickness_burn_occur',
#   '155_degree_fahrenheit',
#   'f323_483.25(h',
#   'free_accident',
#   'hazard_supervision',
#   'environment_remain',
#   'free_accident',
#   'hazard_possible',
#   'receive_adequate',
#   'supervision_assistance',
#   'device_prevent',
#   'violate_regulation',
#   'fail_ensure',
#   'receive_adequate',
#   'prevent_accident'],
#  ['skilled_nursing_facility',
#   'hospital_define_section',
#   'skilled_nursing_facility',
#   'patient_bedhold_seven',
#   'facility_violate_regulation',
#   'ready_return_facility',
#   'acute_care_hospital',
#   'physician_order_date',
#   'nausea_vomiting_complaint',
#   'write_bed_hold',
#   'bed_hold_period',
#   'hospital_discharge_planner',
#   'minor_surgical_procedure',
#   'discharge_planner_document',
#   'discharge_skilled_nursing',
#   'hospital_discharge_planner',
#   '2/11/11_11_a.m.',
#   'skilled_nursing_facility',
#   'facility_fail_ensure',
#   'violation_cause_occur',
#   'title_22',
#   'skilled_nursing',
#   'transfer_general',
#   'acute_care',
#   'define_section',
#   '1250(a_health',
#   'safety_code',
#   'skilled_nursing',
#   'bedhold_seven',
#   'violate_regulation'],
#  ['bed_hold_period',
#   'facility_immediately_availability',
#   'resident-_require_service',
#   'facility_ii_eligible',
#   'facility_violate_aforementioned',
#   'ready_return_facility',
#   'diagnosis_include_paraplegia',
#   'severe_protein_calorie',
#   'multiple_pressure_sore',
#   'notice_bed_hold',
#   'bed_hold_notice',
#   'bed_hold_period',
#   'bed_hold_readmission',
#   'contain_follow_statement',
#   'director_case_management',
#   'case_manager_cm',
#   'case_management_note',
#   'case_manager_write',
#   'medical_reason_patient',
#   'case_manager_write',
#   'speak_admission_coordinator',
#   'case_manager_write',
#   'case_manager_write',
#   'case_manager_write',
#   'speak_admission_coordinator',
#   'case_manager_write',
#   'case_manager_write',
#   'case_manager_write',
#   'case_manager_write',
#   'long_term_care'],
#  ['service_high_beingeach',
#   'facility_provide_necessary',
#   'care_service_attain',
#   'assessment_plan_care.the',
#   'high_practical_physical',
#   'time_week_monday',
#   'upper_left_arm',
#   'blood_flow_rate',
#   'blood_flow_rate',
#   'textbook_basic_nursing',
#   'lippincott_williams_wilkin',
#   'care_plan_title',
#   'pale_weak_rn',
#   'record_date_11/7/10',
#   'certified_nurse_aide',
#   'hospital_emergency_department',
#   'administration_breathing_treatment',
#   'emergency_response_team',
#   'emergency_response_team',
#   'ambulance_hospital_emergency',
#   'record_date_11/7/10',
#   'skin_cool_touch',
#   'leave_upper_arm',
#   'pressure_bleed_avf',
#   'nephrologist_physician_specialize',
#   'pressure_bleed_avf',
#   'unable_provide_documentation',
#   'high_beingeach',
#   'provide_necessary',
#   'service_attain']]

# %%
# View another sample of the list of lists to make sure it still includes unigrams and not just trigrams
trigrams[0][40:]
# Out:
# ['datum_set',
#  'date_5/26/11',
#  'independent_activity',
#  'daily_live',
#  'need_extensive',
#  'wheel_walker',
#  'range_motion',
#  '6:30_p.m.',
#  'hot_tea',
#  'cup_tea',
#  'piece_paper',
#  'accidentally_pull',
#  'hot_tea',
#  'skin_peel',
#  'left_thigh',
#  'silvadene_cream',
#  'twice_day',
#  'seven_day',
#  'pressure_ulcer',
#  'skin_peel',
#  'left_thigh',
#  '10:00_a.m.',
#  'cup_tea',
#  'tea_styrofoam',
#  'cup_lid',
#  'piece_paper',
#  'cup_spill',
#  'styrofoam_cup',
#  'regular_coffee',
#  'dietary_service',
#  'supervisor_dss',
#  '10:20_a.m.',
#  '8_ounce',
#  'styrofoam_cup',
#  'wall_adjacent',
#  'coffee_machine',
#  'telephone_interview',
#  '10:35_a.m.',
#  'cup_tea',
#  'styrofoam_cup',
#  'hot_water',
#  'middle_spigot',
#  'coffee_machine',
#  'styrofoam_cup',
#  '9:30_a.m.',
#  'plastic_coffee',
#  'hot_water',
#  'middle_spigot',
#  'coffee_machine',
#  'water_temperature',
#  'degree_fahrenheit',
#  'study_thermal',
#  '3rd_degree',
#  'thickness_burn',
#  '155_degree',
#  'prevent_accidental',
#  'hot_cup',
#  'tea_styrofoam',
#  'violation_direct',
#  'immediate_relationship',
#  'health_safety',
#  'f323',
#  '483.25(h',
#  'free',
#  'accident',
#  'hazard',
#  'supervision',
#  'device',
#  'facility',
#  'ensure',
#  'resident',
#  'environment',
#  'remain',
#  'free',
#  'accident',
#  'hazard',
#  'possible',
#  'resident',
#  'receive',
#  'adequate',
#  'supervision',
#  'assistance',
#  'device',
#  'prevent',
#  'accident',
#  'facility',
#  'violate',
#  'regulation',
#  'fail',
#  'ensure',
#  'resident',
#  '1',
#  'receive',
#  'adequate',
#  'supervision',
#  'prevent',
#  'accident',
#  'give',
#  'hot',
#  'water',
#  'styrofoam',
#  'cup',
#  'intend',
#  'staff',
#  'use',
#  'cup',
#  'spill',
#  'lap',
#  'cause',
#  '14',
#  'centimeter',
#  'cm',
#  '7',
#  'cm',
#  'burn',
#  'left',
#  'thigh',
#  '5.5',
#  'x',
#  '3',
#  'inch',
#  '4',
#  'cm',
#  '3',
#  'cm',
#  'area',
#  '1.5',
#  'x',
#  '1',
#  'inch',
#  'burn',
#  'area',
#  'thickness',
#  'skin',
#  'peel',
#  'record',
#  'review',
#  '8/3/11',
#  'show',
#  'resident',
#  '1',
#  '93',
#  'year',
#  'old',
#  'woman',
#  'reside',
#  'facility',
#  '3',
#  'year',
#  'accord',
#  'recent',
#  'minimum',
#  'datum',
#  'set',
#  'md',
#  'quarterly',
#  'assessment',
#  'date',
#  '5/26/11',
#  'independent',
#  'activity',
#  'daily',
#  'live',
#  'bathing',
#  'need',
#  'extensive',
#  'assistance',
#  'help',
#  'person',
#  'bathing',
#  'cognitively',
#  'aware',
#  'know',
#  'date',
#  'month',
#  'year',
#  'use',
#  'wheel',
#  'walker',
#  'wheelchair',
#  'range',
#  'motion',
#  'joint',
#  '7/27/11',
#  'accord',
#  'nurse',
#  "'s",
#  'note',
#  'write',
#  '6:30',
#  'p.m.',
#  'resident',
#  'request',
#  'hot',
#  'tea',
#  'receptionist',
#  'cup',
#  'tea',
#  'piece',
#  'paper',
#  'resident',
#  'accidentally',
#  'pull',
#  'hot',
#  'tea',
#  'spill',
#  'cause',
#  'redness',
#  'burn',
#  'skin',
#  'peel',
#  'left',
#  'thigh',
#  'physician',
#  'call',
#  'order',
#  'silvadene',
#  'cream',
#  'burn',
#  'wound',
#  'treatment',
#  'apply',
#  'twice',
#  'day',
#  'seven',
#  'day',
#  'accord',
#  'weekly',
#  'non',
#  'pressure',
#  'ulcer',
#  'record',
#  'date',
#  '7/27/11',
#  'wound',
#  'describe',
#  '14',
#  'x',
#  '7',
#  'centimeter',
#  'burn',
#  'redness/',
#  'skin',
#  'peel',
#  'l',
#  'left',
#  'thigh',
#  '4',
#  'centimeter',
#  '3',
#  'centimeter',
#  'interview',
#  'resident',
#  '1',
#  '8/3/11',
#  '10:00',
#  'a.m.',
#  'state',
#  'ask',
#  'cup',
#  'tea',
#  'receptionist',
#  'bring',
#  'tea',
#  'styrofoam',
#  'cup',
#  'lid',
#  'piece',
#  'paper',
#  'absorb',
#  'spill',
#  'state',
#  'pull',
#  'paper',
#  'mistake',
#  'cup',
#  'spill',
#  'say',
#  'styrofoam',
#  'cup',
#  'topple',
#  'regular',
#  'coffee',
#  'cup',
#  'plastic',
#  'mug',
#  'not',
#  'happen',
#  'sturdy',
#  'dietary',
#  'service',
#  'supervisor',
#  'dss',
#  'state',
#  'interview',
#  '8/3/11',
#  '10:20',
#  'a.m.',
#  'take',
#  'place',
#  'kitchen',
#  '8',
#  'ounce',
#  'styrofoam',
#  'cup',
#  'keep',
#  'dispenser',
#  'wall',
#  'adjacent',
#  'coffee',
#  'machine',
#  'staff',
#  'use',
#  'serve',
#  'residents.in',
#  'telephone',
#  'interview',
#  '8/3/11',
#  '10:35',
#  'a.m.',
#  'receptionist',
#  'state',
#  'evening',
#  '7/27/11',
#  'go',
#  'kitchen',
#  'cup',
#  'tea',
#  'resident',
#  '1',
#  'sit',
#  'lobby',
#  'state',
#  'go',
#  'kitchen',
#  'take',
#  'styrofoam',
#  'cup',
#  'hot',
#  'water',
#  'middle',
#  'spigot',
#  'coffee',
#  'machine',
#  'bring',
#  'lid',
#  'resident',
#  'state',
#  'inform',
#  'styrofoam',
#  'cup',
#  'give',
#  'resident',
#  '9:30',
#  'a.m.',
#  '8/3/11',
#  'dss',
#  'bring',
#  'plastic',
#  'coffee',
#  'mug',
#  'hot',
#  'water',
#  'middle',
#  'spigot',
#  'coffee',
#  'machine',
#  'lobby',
#  'dss',
#  'different',
#  'thermometer',
#  'measure',
#  'water',
#  'temperature',
#  '160',
#  'degree',
#  'fahrenheit',
#  'accord',
#  'moritz',
#  'a.r',
#  'henrique',
#  'f.c.jr',
#  '1947',
#  'study',
#  'thermal',
#  'injury',
#  'ii',
#  'relative',
#  'importance',
#  'time',
#  'surface',
#  'temperature',
#  'causation',
#  'cutaneous',
#  'burn',
#  'j',
#  'pathology',
#  '23',
#  '695',
#  '720',
#  'time',
#  'require',
#  '3rd',
#  'degree',
#  'thickness',
#  'burn',
#  'occur',
#  '155',
#  'degree',
#  'fahrenheit',
#  '1',
#  'second',
#  'facility',
#  'fail',
#  'prevent',
#  'accidental',
#  'burning',
#  'resident',
#  '1',
#  "'s",
#  'leave',
#  'thigh',
#  'give',
#  'hot',
#  'cup',
#  'tea',
#  'styrofoam',
#  'cup',
#  'stable',
#  'vessel',
#  'intend',
#  'resident',
#  'use',
#  'fall',
#  'lap',
#  'pull',
#  'paper',
#  'cup.this',
#  'violation',
#  'direct',
#  'immediate',
#  'relationship',
#  'health',
#  'safety',
#  'resident',
#  '1']

# %%
# Add the trigrams to the database and save it to disk.
working.loc[:, 'TRIGRAMS'] = trigrams
working.to_csv("../data/interim/trigrams3.csv")
