# %%
import pandas as pd
import numpy as np
import spacy
import re
from scipy import stats

from gensim.models import Phrases, LdaModel, CoherenceModel, Word2Vec
from gensim.models.word2vec import LineSentence
from gensim.corpora import Dictionary, MmCorpus
from gensim.test.utils import datapath

import pyLDAvis
import pyLDAvis.gensim

from ast import literal_eval

# %%
# Import model from disc
lda_model =  LdaModel.load("../models/ldatrain")
dct = Dictionary.load_from_text("../models/ldatrain_dct")

# %%
# Test that import was successful
for topic in range(2):
    print([(a, round(b*100, 2)) for (a, b) in lda_model.show_topic(topic, topn=5)])
    print("\n")
# Out:
# [('oxygen', 0.51), ('fluid', 0.51), ('weight', 0.37), ('food', 0.37), ('catheter', 0.34)]
#
#
# [('alarm', 0.39), ('elopement', 0.34), ('ln', 0.29), ('wander', 0.28), ('july', 0.27)]

# %%
data = pd.read_csv("../data/interim/trigrams3.csv")
data = data.drop(['Unnamed: 0'], axis=1)
data['TRIGRAMS'] = data['TRIGRAMS'].apply(literal_eval)
data.head()
# Out:
#         NUM                                           FACILITY        DATE  \
# 0  20008964                          FREMONT HEALTHCARE CENTER  2012-02-01
# 1  20009068                         WILLOW TREE NURSING CENTER  2012-03-02
# 2  20009069  KINDRED NURSING AND REHABILITATION - YGNACIO V...  2012-03-02
# 3  20009078              BAY VIEW REHABILITATION HOSPITAL, LLC  2012-03-05
# 4  20009082                    LONE TREE CONVALESCENT HOSPITAL  2012-03-06
#
#       FINE                                          NARRATIVE  \
# 0    750.0  F323 483.25(h) FREE OF ACCIDENT HAZARDS/SUPERV...
# 1    750.0  Title 22 72520 (a) If a patient of a skilled n...
# 2    750.0  483.12(b) (3) Permitting Resident to Return to...
# 3  37500.0  483.25 PROVIDE CARE/SERVICES FOR HIGHEST WELL ...
# 4    600.0  T22 DIV5 CH3 ART3-72311(a)(1)(A) Nursing Servi...
#
#                                             TRIGRAMS
# 0  [hazard_supervision_device, device_prevent_acc...
# 1  [skilled_nursing_facility, hospital_define_sec...
# 2  [bed_hold_period, facility_immediately_availab...
# 3  [service_high_beingeach, facility_provide_nece...
# 4  [nursing_service_shall, include_limit_followin...

# %%
def remove_numbers(corpus):
    regexp = re.compile(r'^[0-9]*$')
    return [[word for word in line if not regexp.search(word)] for line in corpus]
full_corpus = data['TRIGRAMS'].tolist()
full_corpus = remove_numbers(full_corpus)
full_dct = dct
full_corpus_nums = [full_dct.doc2bow(text) for text in full_corpus]

# %%
# Test that topics have actually been assigned to documents
lda_model.get_document_topics(full_corpus_nums[2])
# Out:
# [(0, 0.23195742), (2, 0.04504645), (3, 0.6843919), (6, 0.019357733)]

# %%
# Write a function to identify the topic most strongly associated with each document

def get_best_topic(document, model):
    best_topic = None
    best_prob = 0
    candidates = model.get_document_topics(document)
    for (topic, prob) in candidates:
        if prob > best_prob:
            best_topic = topic
            best_prob = prob
    return best_topic

# %%
# Test the function
get_best_topic(full_corpus_nums[2], lda_model)
# Out:
# 3

# %%
get_best_topic(full_corpus_nums[1828], lda_model)
# Out:
# 2

# %%
# %%time

# Assign each document in the corpus to a particular topic
data.loc[:, 'TOPIC'] = [get_best_topic(full_corpus_nums[row], lda_model) 
                        for row in range(len(data))]
# Out:
# Wall time: 2.51 s

# %%
data.head()
# Out:
#         NUM                                           FACILITY        DATE  \
# 0  20008964                          FREMONT HEALTHCARE CENTER  2012-02-01
# 1  20009068                         WILLOW TREE NURSING CENTER  2012-03-02
# 2  20009069  KINDRED NURSING AND REHABILITATION - YGNACIO V...  2012-03-02
# 3  20009078              BAY VIEW REHABILITATION HOSPITAL, LLC  2012-03-05
# 4  20009082                    LONE TREE CONVALESCENT HOSPITAL  2012-03-06
#
#       FINE                                          NARRATIVE  \
# 0    750.0  F323 483.25(h) FREE OF ACCIDENT HAZARDS/SUPERV...
# 1    750.0  Title 22 72520 (a) If a patient of a skilled n...
# 2    750.0  483.12(b) (3) Permitting Resident to Return to...
# 3  37500.0  483.25 PROVIDE CARE/SERVICES FOR HIGHEST WELL ...
# 4    600.0  T22 DIV5 CH3 ART3-72311(a)(1)(A) Nursing Servi...
#
#                                             TRIGRAMS  TOPIC
# 0  [hazard_supervision_device, device_prevent_acc...      4
# 1  [skilled_nursing_facility, hospital_define_sec...      3
# 2  [bed_hold_period, facility_immediately_availab...      3
# 3  [service_high_beingeach, facility_provide_nece...      0
# 4  [nursing_service_shall, include_limit_followin...      2

# %%
train = data.sample(frac=0.8, random_state=42)
test = data.drop(train.index)
train.head()
# Out:
#             NUM                          FACILITY        DATE     FINE  \
# 471    40012798  FRANCISCAN CONVALESCENT HOSPITAL  2016-12-08   2000.0
# 1453  230009521                    WILLOWS CENTER  2012-10-23   2000.0
# 2379  940013137      WOODRUFF CONVALESCENT CENTER  2017-05-31  75000.0
# 1601  240012808          RIALTO POST ACUTE CENTER  2016-12-09  13000.0
# 1094  120010126      POSITIVE DIRECTIONS, INC. #4  2013-12-18   8000.0
#
#                                               NARRATIVE  \
# 471   F 223: 483.13(b) Free From Abuse The resident ...
# 1453  F223 483.13(b), 483.13(c)(1)(i) Free from abus...
# 2379  The citation narrative for this penalty will n...
# 1601  REGULTAION VIOLATION: Health and Safety Code 1...
# 1094  CFR W120 483.410(d)(3) (3) The facility must a...
#
#                                                TRIGRAMS  TOPIC
# 471   [punishment_involuntary_seclusion, physical_ab...      4
# 1453  [abuse_involuntary_seclusion, physical_abuse_c...      4
# 2379  [send_request_toÿchcqdata@cdph.ca.govÿto, obta...      2
# 1601  [health_safety_code, long_term_health, facilit...      2
# 1094  [unannounced_visit_facility, base_observation_...      2

# %%
test.head()
# Out:
#          NUM                         FACILITY        DATE     FINE  \
# 1   20009068       WILLOW TREE NURSING CENTER  2012-03-02    750.0
# 4   20009082  LONE TREE CONVALESCENT HOSPITAL  2012-03-06    600.0
# 11  20009298           VALE HEALTHCARE CENTER  2012-05-14  19000.0
# 16  20009799     WINDSOR ROSEWOOD CARE CENTER  2013-04-25   2000.0
# 19  20009811     WINDSOR ROSEWOOD CARE CENTER  2013-04-25   2000.0
#
#                                             NARRATIVE  \
# 1   Title 22 72520 (a) If a patient of a skilled n...
# 4   T22 DIV5 CH3 ART3-72311(a)(1)(A) Nursing Servi...
# 11  72311 (a) Nursing service shall include, but n...
# 16  ?483.12(a)(2) Transfer and Discharge Requireme...
# 19  F201 ?483.12(a)(2) Transfer and Discharge Requ...
#
#                                              TRIGRAMS  TOPIC
# 1   [skilled_nursing_facility, hospital_define_sec...      3
# 4   [nursing_service_shall, include_limit_followin...      2
# 11  [72311_nursing_service, shall_include_limit, i...      0
# 16  [483.12(a)(2_transfer_discharge, need_meet_fac...      3
# 19  [need_meet_facility, ii_transfer_discharge, 's...      3

# %%
train_means = train.groupby(['TOPIC']).mean()
train_means
# Out:
#                 NUM          FINE
# TOPIC
# 0      4.767727e+08  13830.708185
# 1      4.108533e+08   9240.396491
# 2      4.274328e+08   9852.278826
# 3      1.950702e+08   1987.794118
# 4      4.072702e+08   2360.606432
# 5      4.718002e+08   1709.349593
# 6      4.444039e+08  10403.271028
# 7      3.693922e+08   2039.695238

# %%
test_means = test.groupby(['TOPIC']).mean()
test_means
# Out:
#                 NUM          FINE
# TOPIC
# 0      3.828201e+08  13194.943820
# 1      4.232372e+08  12405.645161
# 2      3.706831e+08   8346.082090
# 3      2.969343e+08   2414.102564
# 4      3.885827e+08   2242.664835
# 5      5.495354e+08   1785.714286
# 6      6.505371e+08  11097.368421
# 7      2.825921e+08   2346.774194

# %%
compare_means = pd.DataFrame({"Train": train_means['FINE'], "Test": test_means['FINE']})
compare_means
# Out:
#               Train          Test
# TOPIC
# 0      13830.708185  13194.943820
# 1       9240.396491  12405.645161
# 2       9852.278826   8346.082090
# 3       1987.794118   2414.102564
# 4       2360.606432   2242.664835
# 5       1709.349593   1785.714286
# 6      10403.271028  11097.368421
# 7       2039.695238   2346.774194

# %%
# Display average fines by topic for training set vs. test set
compare_means.index=['Life Support', 'Escape', 'Sores', 'Administration', 'Abuse', 'Theft', 'Diabetes', 'Rashes']
pd.options.display.float_format = '${:,.0f}'.format
compare_means.sort_values('Train', ascending=False)
# Out:
#                  Train    Test
# Life Support   $13,831 $13,195
# Diabetes       $10,403 $11,097
# Sores           $9,852  $8,346
# Escape          $9,240 $12,406
# Abuse           $2,361  $2,243
# Rashes          $2,040  $2,347
# Administration  $1,988  $2,414
# Theft           $1,709  $1,786

# %%
# Average fines are very tightly correlated bewteen topics, r=0.96
stats.pearsonr(compare_means['Train'], compare_means['Test'])
# Out:
# (0.9635930788181462, 0.00011737003354033992)
